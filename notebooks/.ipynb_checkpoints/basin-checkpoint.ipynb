# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
from mpl_toolkits.mplot3d import axes3d
import seaborn as sns

# %%
from mpl_toolkits.mplot3d import axes3d

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.facecolor'] = "none"
plt.rcParams['figure.figsize'] = 9, 9

ax = plt.figure().add_subplot(projection='3d')
X, Y, Z = axes3d.get_test_data(0.01)
Z = Z * 0.5

# Plot the 3D surface
ax.plot_surface(X, Y, Z, 
                edgecolor='royalblue', 
                lw=0.25,
                # rstride=8,
                # cstride=8,
                alpha=0.3)


ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap='plasma')

ax.set(xlim=(-40, 40), 
       ylim=(-40, 40), 
       zlim=(-100, 100),
       xlabel='X',
       ylabel='Y', 
       zlabel='Z')

ax.view_init(elev=20., azim=-15.)

plt.axis('off')

plt.show()

# %%
def ramble(X, Y, Z, t_max=10):
    """A function """
    ny, nx = X.shape

    # initial point
    xi = np.random.choice(nx, 1)[0]
    yi = np.random.choice(ny, 1)[0]

    path = []

    for t in range(t_max):
        
        print(xi, yi, Z[yi, xi])
    
    # print(ny, nx)
    # print(xinit, yinit, X[yinit, xinit])

    



ramble(X, Y, Z, t_max=10)
# Out:
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014
# 258 218 -25.98330937563014

# %%
# ?axes3d.get_test_data
# Out:
# Signature: axes3d.get_test_data(delta=0.05)
# Docstring: Return a tuple X, Y, Z with a test data set.
# File:      ~/.local/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py
# Type:      function

# %%
X.max()
# Out:
# 29.000000000000057
